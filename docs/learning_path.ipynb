# %% [markdown]
# > ## Hello Friends, Welcome to My Little Experiment
#
# > ### Real-Time Formula1 Telemetry Tracking (for now)

# %% [markdown]
# ***
# #### Contents:
# 1. [Brainstorm](#1-brainstorm)
#
# ***

# %% [markdown]
# #### Let's start;
# #### 1) Brainstorm
# - I've just discovered Fastf1 api, and I had spark to do this. Let's do some research.
